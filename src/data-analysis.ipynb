# %%
import pandas as pd

# %%
# Importamos el archivo limpio con los datos que queremos estudiar.
# Hemos obtenido los 3 países que mayor número de ataques han sufrido y las dos actividades que más ataques han recibido por parte de los tiburones.
df_cleaning = pd.read_csv("attacks_cleaning.csv")

# %%
df_cleaning
# Out:
#       Unnamed: 0   Case Number                Date    Year          Type  \
# 0              2    2018.06.09         09-Jun-2018  2018.0       Invalid
# 1              3    2018.06.08         08-Jun-2018  2018.0    Unprovoked
# 2             12  2018.05.13.b         13-May-2018  2018.0    Unprovoked
# 3             15    2018.05.12         12-May-2018  2018.0    Unprovoked
# 4             16    2018.05.09         09-May-2018  2018.0  Questionable
# ...          ...           ...                 ...     ...           ...
# 1402        6201       ND-0122        Beforer 1994     0.0    Unprovoked
# 1403        6213       ND-0106         Before 1962     0.0    Unprovoked
# 1404        6288       ND.0014  Before 17-Jul-1916     0.0    Unprovoked
# 1405        6296       ND.0006         Before 1906     0.0    Unprovoked
# 1406        6299       ND.0003           1900-1905     0.0    Unprovoked
#
#            Country                   Area  \
# 0              USA                 Hawaii
# ...

# %%
# Vamos a ver si se cumple la hipótesis realizada: 
# "Australia es el país donde se produce el mayor número de ataques de tiburones debido a que es el lugar donde más surfistas practican este deporte".

# %%
import seaborn as sns

# %%
sns.countplot(x=df_cleaning.Country, hue=df_cleaning.Activity)
# Out:
# <AxesSubplot:xlabel='Country', ylabel='count'>

# %%
# Observamos que el país donde se producen más ataques de tiburones es en USA y son los surfistas quienes más lo sufren.
# La hipótesis realizada anterioremente no se cumple, porque Australia no es el país que más ataques recibe, aunque si son los surfitas quienes más ataques sufren.
